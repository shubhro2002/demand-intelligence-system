# %%
import sys
sys.path.append("../")

from src.data.load_data import load_all_data

data = load_all_data()

train = data["train"]
features = data["features"]
stores = data["stores"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       2 sys.path.append("../")
#       4 from src.data.load_data import load_all_data
# ----> 6 data = load_all_data()
#       8 train = data["train"]
#       9 features = data["features"]
#
# File c:\Users\subhr\Downloads\demand-intelligence-system\notebooks\..\src\data\load_data.py:25, in load_all_data()
#      23 def load_all_data():
#      24     data = {
# ---> 25         "train": load_csv("train.csv"),
#      26         "test": load_csv("test.csv"),
#      27         "features": load_csv("features.csv"),
#      28         "stores": load_csv("stores.csv")
#      29     }
#      30     return data
#
# File c:\Users\subhr\Downloads\demand-intelligence-system\notebooks\..\src\data\load_data.py:15, in load_csv(file_name)
#      12 file_path = DATA_DIR / file_name
#      14 if not file_path.exists():
# ...

# %%
train.head()
train.info()
train.describe()
